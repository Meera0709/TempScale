# %%
# !pip install geopandas pandas matplotlib folium
# Out:
# ^C
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: C:\Users\meera\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/323.6 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/323.6 kB 435.7 kB/s eta 0:00:01
#    --- ----------------------------------- 30.7/323.6 kB 435.7 kB/s eta 0:00:01
#    --- ----------------------------------- 30.7/323.6 kB 435.7 kB/s eta 0:00:01
#    ------- ------------------------------- 61.4/323.6 kB 233.8 kB/s eta 0:00:02
#    ------- ------------------------------- 61.4/323.6 kB 233.8 kB/s eta 0:00:02
#    -------- ------------------------------ 71.7/323.6 kB 196.3 kB/s eta 0:00:02
#    -------- ------------------------------ 71.7/323.6 kB 196.3 kB/s eta 0:00:02
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import fiona

# %%
# Set config option to restore or create the .shx file
fiona.drvsupport.supported_drivers['ESRI Shapefile'] = 'rw'
fiona.Env(SHAPE_RESTORE_SHX='YES')

# Load the shapefile
gdf = gpd.read_file("/content/sdei-global-uhi-2013.shp")

# Plot the data to visualize
gdf.plot()
plt.show()

# %%
print(uhi_data.head())
print(uhi_data.columns)

# %%
import folium
from folium.plugins import HeatMap

# Convert geometry to latitude and longitude points
uhi_data['centroid'] = uhi_data.geometry.centroid
lat_lon = [(point.y, point.x) for point in uhi_data['centroid']]

# Assuming 'intensity' is the column for UHI values
intensity = uhi_data['intensity_column_name']

# %%
# Create a map centered on the average location
m = folium.Map(location=[average_latitude, average_longitude], zoom_start=5)

# Add heatmap
HeatMap(list(zip([point[0] for point in lat_lon], [point[1] for point in lat_lon], intensity))).add_to(m)

# %%
# Save the map
m.save('uhi_heatmap.html')
